# %% [markdown]
# # 02 - OCR Testing
# This notebook uses the app/services/ modular pipeline.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from app.services.preprocessing import preprocess_image
from app.services.ocr_service import run_ocr
from IPython.display import display, HTML

# %% [markdown]
# ### Run OCR

# %%
image_path = '../sample_bills/dominoz-bill1.jpg'
image = preprocess_image(image_path)
raw_text = run_ocr(image)

# %% [markdown]
# ### Output OCR Result

# %%
lines = [line.strip() for line in raw_text.split('\n') if line.strip()]
print(f"Detected Lines: {len(lines)}")
display(HTML(f'<div style="height: 300px; overflow-y: scroll; border: 1px solid #ccc; padding: 10px; white-space: pre-wrap;">{raw_text}</div>'))
# Out:
# Detected Lines: 40
# <div style="height: 300px; overflow-y: scroll; border: 1px solid #ccc; padding: 10px; white-space: pre-wrap;">4 Se )
# ka
# ; -.... 9% INVOICE 7G \
# ! === Kee FoodWorks Limite
# egies Madhay Nagar. Nagput Nothing makes up for making you ie does |
# “18602100000 state Code: (27) Hope our ’30 minutes delivery prom |
# SUE: 0712-2227001 little something for you. |
# Invoice Nut he ee Love and Happiness |
# - bead . iT Jar: / j /RE R ; ’ ;
# Order eh NESE a Domino’s Pizza
# Delivery |
# ; MR PANDEY. 9604347008 jor |
# eles SANCHAYANT PRESTIGE ion |
# ¢ND FLOOR. SWALAMBI NAGAR . & poemine's Piz .
# NAGPUR - 440010. .
# otate Code:2/ An | —
# 1020917744
# | Reg PAN PM VEG LDD 179.00
# (He) |
# | Reg HI PM Gold Corn 105.00
# = (Cipie
# | Reg HT PM Capsicum 69.00
# __ (Gk)
# 1 Reg HT PM Paneer_On 99.00 |
# (G1)
# SubToat 392 .00
# CGST @ 2.5% 9.80
# SGST/UTGST @ 2.5% 9.80
# Total 411.60
# Due 411.60
# ESTIN:27AABCD1821C1ZB.PAN No. :AABCDI8210
# HSN: 9963
# Brder online at wwW.dominos.co.1n or
# download the new Dominos app. We accept
# Predit Card. Debit Caras. Cash and Pay TM
# Both on Dine-In and Delivery Urders
# ***0regano and Chil | Flakes Sacnets ser
# Bd along with your order are Tor inmedjate
# consumption on . : TO)
# future CONSUMPT ON. *+4
# </div>
